# %% [markdown]
# # House Price Prediction
# ## Problem Definition
# The goal of this project is to build a machine learning model
# that predicts house prices based on different characteristics
# of a house.
# ### Machine Learning Type
# Supervised Learning
# ### Problem Type
# Regression
# ### Target Variable
# price

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/HP/OneDrive/Desktop/ML_prac/datasets/messy_housing_data.csv")

# %%
dfprice
# Out:
#      area_sqft  bedrooms  bathrooms  year_built       price       location
# 0         2696       4.0          1      1962.0  2068779.98         austin
# 1         2017       6.0          4      2008.0  1539208.46  San Francisco
# 2         1592       3.0          3      1991.0    557909.7  San Francisco
# 3         3358       2.0          4      1914.0         NaN        chicago
# 4         1624       2.0          5      1935.0   716945.96  New York City
# ..         ...       ...        ...         ...         ...            ...
# 415       3674       5.0          5         NaN  2664238.68           l.a.
# 416        939       3.0          5      1965.0   491056.77    Los Angeles
# 417       4880       3.0          3      2004.0  3709981.28         boston
# 418       3279       5.0          5      1935.0   1308383.3        Chicago
# 419       1139       2.0          3      1915.0   496344.73            nyc
#
# [420 rows x 6 columns]

# %%
#Shape of the data
df.shape
# Out:
# (420, 6)

# %% [markdown]
# ** What does that mean? **
#
# means we have 420 houses and we have 6 variables/columns.

# %%
#The stucture of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_sqft   420 non-null    int64
#  1   bedrooms    399 non-null    float64
#  2   bathrooms   420 non-null    int64
#  3   year_built  384 non-null    float64
#  4   price       370 non-null    object
#  5   location    420 non-null    object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 19.8+ KB

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# area_sqft      0
# bedrooms      21
# bathrooms      0
# year_built    36
# price         50
# location       0
# dtype: int64

# %%
#Check duplicates
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
#Show the duplicated rows
df[df.duplicated()]
# Out:
#      area_sqft  bedrooms  bathrooms  year_built       price       location
# 400       3857       1.0          4      1970.0  1121087.17    los angeles
# 401       4695       3.0          1      2019.0  1960710.64        Boston
# 402       4360       6.0          3      1950.0  2551135.51  New York city
# 403        650       3.0          2         NaN   136580.26  New York City
# 404       1974       1.0          5         NaN  1147299.91  New York city
# 405        706       4.0          4      1919.0         NaN         austin
# 406       2266       1.0          3      1917.0   850749.66        Chicago
# 407       4281       4.0          4      1976.0  1871382.95         Bostan
# 408        976       NaN          2      2004.0   287451.49    los angeles
# 409       2256       3.0          4      1937.0  1763039.92             sf
# 410       3729       1.0          2      1913.0  1489205.48           l.a.
# 411       2129       5.0          1      2022.0  1108994.39  san francisco
# 412       2592       6.0          4         NaN  1796102.58  New York City
# 413       2874       1.0          1      1994.0  2023776.94         Boston
# 414       1724       2.0          2      1912.0   851969.88          miami
# 415       3674       5.0          5         NaN  2664238.68           l.a.
# 416        939       3.0          5      1965.0   491056.77    Los Angeles
# 417       4880       3.0          3      2004.0  3709981.28         boston
# 418       3279       5.0          5      1935.0   1308383.3        Chicago
# 419       1139       2.0          3      1915.0   496344.73            nyc

# %%
# Shows both the original rows and their duplicate copies, making it easier to understand what's happening.
df[df.duplicated(keep=False)].sort_values(by=["area_sqft", "bedrooms"])
# Out:


# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Investigating the price column
df['price'].head(20)
# Out:
# 0     2068779.98
# 1     1539208.46
# 2       557909.7
# 3            NaN
# 4      716945.96
# 5      574438.17
# 6            NaN
# 7            NaN
# 8      1974364.8
# 9     1489205.48
# 10    3830378.09
# 11     542187.73
# 12    1461241.11
# 13           NaN
# 14    1165755.41
# 15    1637513.07
# 16     2965470.5
# 17     612815.74
# 18    2470823.55
# 19     446664.75
# Name: price, dtype: object

# %%
df['price'].dtype
# Out:
# dtype('O')

# %%
df['price'].unique()
# Out:
# array(['2068779.98', '1539208.46', '557909.7', nan, '716945.96',
#        '574438.17', '1974364.8', '1489205.48', '3830378.09', '542187.73',
#        '1461241.11', '1165755.41', '1637513.07', '2965470.5', '612815.74',
#        '2470823.55', '446664.75', '2499620.89', '25710', '1082617.93',
#        '329772.59', '693954.16', '1253145.14', '524115.14', '2023729.99',
#        '1297552.1', '363624.94', '814621.64', '2551135.51', '1769596.1',
#        '659706.61', '526823.25', '1053573.57', '1175350.02', '1693434.38',
#        '2664238.68', '170067.87', '1409945.42', '2407961.69',
#        '1593555.06', '1741343.06', '1061991.43', '349256.54',
#        '2884846.24', '790682.37', '575126.88', '1056683.16', '1796102.58',
#        '605836.19', '2615033.93', 'unavailable', '1595071.35',
#        '2279975.0', '568549.58', '541651.91', '2084710.67', '528502.71',
#        '438478.83', '1353744.45', '39240', '451972.47', '991381.15',
#        '2023776.94', '1060132.81', '937610.47', '448012.63', '2440843.48',
#        '413490.67', '1270502.83', '835217.52', '875633.15', '503593.13',
#        '800781.74', '1785314.93', '45320', '950628.2', '658374.8',
#        '186063.31', '212647.47', '1580299.45', '2960272.36', '1147299.91',
#        '1871382.95', '172438.3', '675777.83', '362489.87', '1174522.94',
#        '1463021.77', '942147.81', '1004732.97', '2462392.96',
#        '2465782.04', '2778758.87', '2977418.17', '425554.99', '214869.47',
#        '2132692.92', '909770.93', '967668.73', '900734.1', '1268659.1',
#        '1553357.9', '1223353.07', '1839499.27', '1723235.92', '430349.95',
#        '1180883.15', '650848.36', '465190.41', '2820439.13', '1763039.92',
#        '881513.06', '586529.68', '2517932.58', '1535164.26', '851969.88',
#        '207047.52', '1436359.58', '654445.57', '1453589.77', '2233023.79',
#        '793251.31', '296748.48', '1384232.23', '289097.55', '444309.83',
#        '1848997.98', '423779.71', '1564597.95', '2524988.67',
#        '2884901.42', '520811.97', '264539.54', '1187477.73', '462581.17',
#        '1841816.99', '1566276.54', '286663.88', '2707784.31',
#        '1032101.39', '1450655.06', '1989318.43', '352665.76',
#        '1823636.27', '1140329.2', '738263.18', '2043035.66', '3674840.2',
#        '327418.38', '790824.04', '1634583.09', '2645115.11', '878336.25',
#        '30610', '466547.16', '1591216.83', '1344815.64', '892018.53',
#        '1372000', '222322.28', '1153023.94', '2234192.01', '1105287.88',
#        '1340271.35', '752174.48', '2933462.44', '480805.19', '2522591.82',
#        '1511764.18', '801948.16', '2086097.89', '3849794.96', '620810.93',
#        '287838.02', '793818.83', '2790380.09', '335325.85', '1181720.05',
#        '363602.54', '616750.2', '1119010.38', '800398.59', '973470.17',
#        '163225.47', '1727298.95', '1367411.12', '2993615.69',
#        '1121087.17', '136580.26', '1207288.24', '915519.5', '545660.07',
#        '1408848.74', '2032036.44', '2083841.53', '1197137.43',
#        '1606234.96', '2393032.66', '1304407.68', '2089908.1',
#        '1800492.07', '745706.57', '1157123.09', '874170.41', '1308383.3',
#        '1599628.63', '2834480.46', '515892.38', '1683788.56',
#        '1463526.87', '1912999.51', '1037813.7', '914799.17', '28660',
#        '898713.01', '160487.29', '3384779.81', '1663202.26', '1306406.22',
#        '2759785.73', '547358.12', '951430.55', '1819079.41', '23880',
#        '1367343.29', '1030980.32', '2791783.96', '2512000', '436777.16',
#        '258950.59', '845113.36', '1508675.3', '2122531.32', '287451.49',
#        '922509.43', '1192482.65', '899893.62', '2123954.19', '1136104.17',
#        '294226.34', '3170755.68', '1204288.98', '1172163.63',
#        '2711444.58', '491056.77', '1856510.25', '1960710.64',
#        '1209677.33', '7496000', '2058927.13', '3018573.11', '751621.33',
#        '1428780.33', '3048157.67', '2468978.22', '3245460.43',
#        '477966.23', '2393205.73', '1072721.02', '3267890.51',
#        '2221152.59', '1044583.62', '721928.84', '1266339.97',
#        '1862541.91', '3037608.45', '1900343.44', '1190441.71',
#        '2084071.95', '2213316.45', '326248.87', '146828.25', '1308513.56',
#        '232185.73', '927805.86', '1273157.18', '1943093.42', '1024222.28',
#        '655768.37', '2078031.26', '2203642.12', '9640', '1205054.09',
#        '228851.74', '1630636.24', '589115.68', '1309602.86', '1924329.11',
#        '850749.66', '1218363.42', '1681842.38', '1864854.82',
#        '2118778.33', '758983.81', '3036561.27', '8520000', '3042929.38',
#        '1362884.53', '18770', '800163.61', '3052191.32', '1767016.79',
#        '814352.19', '2144872.77', '1058963.96', '1044438.33',
#        '2218409.79', '628410.66', '1176009.9', '1281517.74', '777475.57',
#        '325690.36', '1971527.08', '1178375.89', '3472565.82', '959092.83',
#        '1108994.39', '1565358.45', '143862.87', '703873.27', '1114540.31',
#        '609922.46', '2696554.33', '3345120.68', '1036463.92', '711503.89',
#        '514715.97', '740252.11', '509088.87', '2576977.93', '3709981.28',
#        '579740.59', '1454516.52', '496344.73', '1572060.51', '403576.59',
#        '587973.39', '2365404.09', '2749555.58', '970356.55', '261474.39',
#        '850433.91', '1433478.51', '960473.13', '1373722.24', '1274725.66'],
#       dtype=object)

# %%
df['price'].value_counts(dropna=False).head(10)
# Out:
# price
# NaN            49
# unavailable     7
# 2068779.98      1
# 1539208.46      1
# 557909.7        1
# 716945.96       1
# 574438.17       1
# 1974364.8       1
# 1489205.48      1
# 3830378.09      1
# Name: count, dtype: int64

# %%
(df['price'] == 'unavailable').sum()
# Out:
# np.int64(7)

# %%
df['price'] = pd.to_numeric(df['price'], errors = "coerce")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9016\3767289678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'] = pd.to_numeric(df['price'], errors = "coerce")

# %%
df['price'].value_counts()
# Out:
# price
# 2068779.98    1
# 1539208.46    1
# 557909.70     1
# 716945.96     1
# 574438.17     1
#              ..
# 850433.91     1
# 1433478.51    1
# 960473.13     1
# 1373722.24    1
# 1274725.66    1
# Name: count, Length: 344, dtype: int64
